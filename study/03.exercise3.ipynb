# %%
import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
titanic_df = pd.read_csv(url)

titanic_df.to_csv("titanic.csv", index=False)
print("Downloaded and saved as titanic.csv")
titanic_df.head()
