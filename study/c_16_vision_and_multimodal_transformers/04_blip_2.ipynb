# %%
from transformers import Blip2Processor, Blip2ForConditionalGeneration
import torch
import torch.nn as nn

device = "cuda"

# %%
import urllib
import urllib.request
from PIL import Image


model_id = "Salesforce/blip2-opt-2.7b"
blip2_processor = Blip2Processor.from_pretrained(model_id)
blip2_model = Blip2ForConditionalGeneration.from_pretrained(
    model_id, device_map=device, dtype=torch.float16
)

image_url = "http://images.cocodataset.org/val2017/000000039769.jpg"  # two cats
image = Image.open(urllib.request.urlopen(image_url))
inputs = blip2_processor(image=image, return_tensors="pt")
inputs = inputs.to(device, dtype=torch.float16)
with torch.no_grad():
    generated_ids = blip2_model.generate(**inputs)

generated_text = blip2_processor.batch_decode(generated_ids)
generated_text
# Out:
# processor_config.json:   0%|          | 0.00/68.0 [00:00<?, ?B/s]
# e:\Program\handson-mlp\.venv\Lib\site-packages\huggingface_hub\file_download.py:137: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\User\.cache\huggingface\hub\models--Salesforce--blip2-opt-2.7b. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# preprocessor_config.json:   0%|          | 0.00/432 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.03k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/882 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/548 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.56M [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/122k [00:00<?, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 8
#       4
#       5
#       6 model_id = "Salesforce/blip2-opt-2.7b"
#       7 blip2_processor = Blip2Processor.from_pretrained(model_id)
# ----> 8 blip2_model = Blip2ForConditionalGeneration.from_pretrained(
#       9     model_id, device_map=device, dtype=torch.float16
#      10 )
#      11
#
# File e:\Program\handson-mlp\.venv\Lib\site-packages\transformers\modeling_utils.py:4222, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, fusion_config, disable_mmap, *model_args, **kwargs)
#    4217     logger.warning_once(
#    4218         "A kernel_config was provided but use_kernels is False; setting use_kernels=True automatically. To suppress this warning, explicitly set use_kernels to True."
#    4219     )
#    4220     use_kernels = True
# -> 4222 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4223     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4224     variant=variant,
#    4225     gguf_file=gguf_file,
#    4226     use_safetensors=use_safetensors,
#    4227     download_kwargs=download_kwargs_with_commit,
#    4228     user_agent=user_agent,
#    4229     is_remote_code=cls.is_remote_code(),
#    4230     transformers_explicit_filename=getattr(config, "transformers_weights", None),
#    4231     tqdm_class=tqdm_class,
#    4232 )
#    4234 is_quantized = hf_quantizer is not None
#    4236 # Find the correct dtype based on current state
#
# File e:\Program\handson-mlp\.venv\Lib\site-packages\transformers\modeling_utils.py:797, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, variant, gguf_file, use_safetensors, user_agent, is_remote_code, transformers_explicit_filename, download_kwargs, tqdm_class)
#     795 sharded_metadata = None
#     796 if is_sharded:
# --> 797     checkpoint_files, sharded_metadata = get_checkpoint_shard_files(
#     798         pretrained_model_name_or_path,
#     799         resolved_archive_file,
#     800         cache_dir=cache_dir,
#     801         force_download=force_download,
#     802         proxies=proxies,
#     803         local_files_only=local_files_only,
#     804         token=token,
#     805         user_agent=user_agent,
#     806         revision=revision,
#     807         subfolder=subfolder,
#     808         _commit_hash=commit_hash,
#     809         tqdm_class=tqdm_class,
#     810     )
#     811 else:
#     812     checkpoint_files = [resolved_archive_file] if pretrained_model_name_or_path is not None else None
#
# File e:\Program\handson-mlp\.venv\Lib\site-packages\transformers\utils\hub.py:894, in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, local_files_only, token, user_agent, revision, subfolder, _commit_hash, tqdm_class, **deprecated_kwargs)
#     890     return shard_filenames, sharded_metadata
#     892 # At this stage pretrained_model_name_or_path is a model identifier on the Hub. Try to get everything from cache,
#     893 # or download the files
# --> 894 cached_filenames = cached_files(
#     895     pretrained_model_name_or_path,
#     896     shard_filenames,
#     897     cache_dir=cache_dir,
#     898     force_download=force_download,
#     899     proxies=proxies,
#     900     local_files_only=local_files_only,
#     901     token=token,
#     902     user_agent=user_agent,
#     903     revision=revision,
#     904     subfolder=subfolder,
#     905     _commit_hash=_commit_hash,
#     906     tqdm_class=tqdm_class,
#     907 )
#     909 return cached_filenames, sharded_metadata
#
# File e:\Program\handson-mlp\.venv\Lib\site-packages\transformers\utils\hub.py:527, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     524     # Any other Exception type should now be re-raised, in order to provide helpful error messages and break the execution flow
#     525     # (EntryNotFoundError will be treated outside this block and correctly re-raised if needed)
#     526     elif not isinstance(e, EntryNotFoundError):
# --> 527         raise e
#     529 resolved_files = [
#     530     _get_cache_file_to_return(path_or_repo_id, filename, cache_dir, revision) for filename in full_filenames
#     531 ]
#     532 # If there are any missing file and the flag is active, raise
#
# File e:\Program\handson-mlp\.venv\Lib\site-packages\transformers\utils\hub.py:452, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     437         hf_hub_download(
#     438             path_or_repo_id,
#     439             filenames[0],
#    (...)    449             tqdm_class=tqdm_class,
#     450         )
#     451     else:
# --> 452         snapshot_download(
#     453             path_or_repo_id,
#     454             allow_patterns=full_filenames,
#     455             repo_type=repo_type,
#     456             revision=revision,
#     457             cache_dir=cache_dir,
#     458             user_agent=user_agent,
#     459             force_download=force_download,
#     460             proxies=proxies,
#     461             token=token,
#     462             local_files_only=local_files_only,
#     463             tqdm_class=tqdm_class,
#     464         )
#     466 except Exception as e:
#     467     # We cannot recover from them
#     468     if isinstance(e, RepositoryNotFoundError) and not isinstance(e, GatedRepoError):
#
# File e:\Program\handson-mlp\.venv\Lib\site-packages\huggingface_hub\utils\_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File e:\Program\handson-mlp\.venv\Lib\site-packages\huggingface_hub\_snapshot_download.py:456, in snapshot_download(repo_id, repo_type, revision, cache_dir, local_dir, library_name, library_version, user_agent, etag_timeout, force_download, token, local_files_only, allow_patterns, ignore_patterns, max_workers, tqdm_class, headers, endpoint, dry_run)
#     434 def _inner_hf_hub_download(repo_file: str) -> None:
#     435     results.append(
#     436         hf_hub_download(  # type: ignore
#     437             repo_id,
#    (...)    453         )
#     454     )
# --> 456 thread_map(
#     457     _inner_hf_hub_download,
#     458     filtered_repo_files,
#     459     desc=tqdm_desc,
#     460     max_workers=max_workers,
#     461     tqdm_class=tqdm_class,
#     462 )
#     464 bytes_progress.set_description("Download complete")
#     466 if dry_run:
#
# File e:\Program\handson-mlp\.venv\Lib\site-packages\tqdm\contrib\concurrent.py:69, in thread_map(fn, *iterables, **tqdm_kwargs)
#      55 """
#      56 Equivalent of `list(map(fn, *iterables))`
#      57 driven by `concurrent.futures.ThreadPoolExecutor`.
#    (...)     66     [default: max(32, cpu_count() + 4)].
#      67 """
#      68 from concurrent.futures import ThreadPoolExecutor
# ---> 69 return _executor_map(ThreadPoolExecutor, fn, *iterables, **tqdm_kwargs)
#
# File e:\Program\handson-mlp\.venv\Lib\site-packages\tqdm\contrib\concurrent.py:51, in _executor_map(PoolExecutor, fn, *iterables, **tqdm_kwargs)
#      47 with ensure_lock(tqdm_class, lock_name=lock_name) as lk:
#      48     # share lock in case workers are already using `tqdm`
#      49     with PoolExecutor(max_workers=max_workers, initializer=tqdm_class.set_lock,
#      50                       initargs=(lk,)) as ex:
# ---> 51         return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#
# File e:\Program\handson-mlp\.venv\Lib\site-packages\tqdm\notebook.py:250, in tqdm_notebook.__iter__(self)
#     248 try:
#     249     it = super().__iter__()
# --> 250     yield from it
#     251 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#     252 except:  # NOQA
#
# File e:\Program\handson-mlp\.venv\Lib\site-packages\tqdm\std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\concurrent\futures\_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\concurrent\futures\_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File e:\Program\handson-mlp\.venv\Lib\site-packages\huggingface_hub\_snapshot_download.py:436, in snapshot_download.<locals>._inner_hf_hub_download(repo_file)
#     434 def _inner_hf_hub_download(repo_file: str) -> None:
#     435     results.append(
# --> 436         hf_hub_download(  # type: ignore
#     437             repo_id,
#     438             filename=repo_file,
#     439             repo_type=repo_type,
#     440             revision=commit_hash,
#     441             endpoint=endpoint,
#     442             cache_dir=cache_dir,
#     443             local_dir=local_dir,
#     444             library_name=library_name,
#     445             library_version=library_version,
#     446             user_agent=user_agent,
#     447             etag_timeout=etag_timeout,
#     448             force_download=force_download,
#     449             token=token,
#     450             headers=headers,
#     451             tqdm_class=_AggregatedTqdm,  # type: ignore
#     452             dry_run=dry_run,
#     453         )
#     454     )
#
# File e:\Program\handson-mlp\.venv\Lib\site-packages\huggingface_hub\utils\_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File e:\Program\handson-mlp\.venv\Lib\site-packages\huggingface_hub\file_download.py:1015, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#     994     return _hf_hub_download_to_local_dir(
#     995         # Destination
#     996         local_dir=local_dir,
#    (...)   1012         dry_run=dry_run,
#    1013     )
#    1014 else:
# -> 1015     return _hf_hub_download_to_cache_dir(
#    1016         # Destination
#    1017         cache_dir=cache_dir,
#    1018         # File info
#    1019         repo_id=repo_id,
#    1020         filename=filename,
#    1021         repo_type=repo_type,
#    1022         revision=revision,
#    1023         # HTTP info
#    1024         endpoint=endpoint,
#    1025         etag_timeout=etag_timeout,
#    1026         headers=hf_headers,
#    1027         token=token,
#    1028         # Additional options
#    1029         local_files_only=local_files_only,
#    1030         force_download=force_download,
#    1031         tqdm_class=tqdm_class,
#    1032         dry_run=dry_run,
#    1033     )
#
# File e:\Program\handson-mlp\.venv\Lib\site-packages\huggingface_hub\file_download.py:1237, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1234 # Local file doesn't exist or etag isn't a match => retrieve file from remote (or cache)
#    1236 with WeakFileLock(lock_path):
# -> 1237     _download_to_tmp_and_move(
#    1238         incomplete_path=Path(blob_path + ".incomplete"),
#    1239         destination_path=Path(blob_path),
#    1240         url_to_download=url_to_download,
#    1241         headers=headers,
#    1242         expected_size=expected_size,
#    1243         filename=filename,
#    1244         force_download=force_download,
#    1245         etag=etag,
#    1246         xet_file_data=xet_file_data,
#    1247         tqdm_class=tqdm_class,
#    1248     )
#    1249     if not os.path.exists(pointer_path):
#    1250         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File e:\Program\handson-mlp\.venv\Lib\site-packages\huggingface_hub\file_download.py:1860, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, headers, expected_size, filename, force_download, etag, xet_file_data, tqdm_class)
#    1858 if xet_file_data is not None and is_xet_available():
#    1859     logger.debug("Xet Storage is enabled for this repo. Downloading file from Xet Storage..")
# -> 1860     xet_get(
#    1861         incomplete_path=tmp_path,
#    1862         xet_file_data=xet_file_data,
#    1863         headers=headers,
#    1864         expected_size=expected_size,
#    1865         displayed_filename=filename,
#    1866         tqdm_class=tqdm_class,
#    1867     )
#    1868 else:
#    1869     if xet_file_data is not None and not constants.HF_HUB_DISABLE_XET:
#
# File e:\Program\handson-mlp\.venv\Lib\site-packages\huggingface_hub\file_download.py:565, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, tqdm_class, _tqdm_bar)
#     562     _prev = current
#     564 try:
# --> 565     with session.new_file_download_group(
#     566         token_refresh_url=xet_file_data.refresh_route,
#     567         token_refresh_headers=headers,
#     568         custom_headers=xet_headers,
#     569         progress_callback=_on_progress,
#     570     ) as group:
#     571         group.start_download_file(
#     572             XetFileInfo(xet_file_data.file_hash, expected_size), str(incomplete_path.absolute())
#     573         )
#     574 except KeyboardInterrupt:
#
# RuntimeError: Task error: File reconstruction error: IO Error: There is not enough space on the disk. (os error 112)

# %%
generated_text = blip2_processor.batch_decode(generated_ids, skip_special_tokens=True)
