# %%
# %%capture
import sys
# !{sys.executable} -m spacy download en_core_web_sm
# !{sys.executable} -m spacy download de_core_news_sm

# %%
import spacy

spacy_en = spacy.load("en_core_web_sm") # 영어 토큰화(tokenization)
spacy_de = spacy.load("de_core_news_sm") # 독일어 토큰화(tokenization)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import spacy
#       2
#       3 spacy_en = spacy.load("en_core_web_sm") # 영어 토큰화(tokenization)
#       4 spacy_de = spacy.load("de_core_news_sm") # 독일어 토큰화(tokenization)
#
# ModuleNotFoundError: No module named 'spacy'

# %%
tokenized = spacy_en.tokenizer("i am a graduate student.")

for i, token in enumerate(tokenized):
    print(f"idx {i}:{token}")
# Out:
# idx 0:i
# idx 1:am
# idx 2:a
# idx 3:graduate
# idx 4:student
# idx 5:.

# %%
#reverse text order and return
def tokenize_de(text:str): 
    return [token for token in spacy_de.tokenizer(text)][::-1]

def tokenize_en(text:str):
    return [token for token in spacy_en.tokenizer(text)]

# %%
from datasets import load_dataset
dataset = load_dataset("bentrevett/multi30k")
train_data = dataset["train"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from datasets import load_dataset
#       2 dataset = load_dataset("bentrevett/multi30k")
#       3 train_data = dataset["train"]
#
# File e:\Program\handson-mlp\.venv\Lib\site-packages\datasets\__init__.py:17
#       1 # Copyright 2020 The HuggingFace Datasets Authors and the TensorFlow Datasets Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 __version__ = "4.4.1"
# ---> 17 from .arrow_dataset import Column, Dataset
#      18 from .arrow_reader import ReadInstruction
#      19 from .builder import ArrowBasedBuilder, BuilderConfig, DatasetBuilder, GeneratorBasedBuilder
#
# ...
